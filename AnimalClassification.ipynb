# %% [markdown]
# Transforming the .jpeg in to vectors

# %%
import os 
path=r'datasets/Animal'
l=[]
for root,dir,files in os.walk(path):
    for file in files:
        first_word=file.split('-',1)
        
        l.append(first_word[0])
        print(first_word[0])
# Out:
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BEAR
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# BIRD
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# CAT
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# COW
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DEER
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOG
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# DOLPHIN
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# ELEPHANT
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# GIRAFFE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# HORSE
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# KANGAROO
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# LION
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# PANDA
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# TIGER
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA
# ZEBRA

# %%
uniqe_values=list(set(l))
print(uniqe_values)
# Out:
# ['TIGER', 'DOG', 'GIRAFFE', 'HORSE', 'BIRD', 'COW', 'BEAR', 'DEER', 'PANDA', 'ELEPHANT', 'ZEBRA', 'CAT', 'DOLPHIN', 'KANGAROO', 'LION']

# %%
num_lists=[]
for i in range(len(uniqe_values)):
    num_lists.append(i)

# %%
identety_dic={}
for uniqe_value,num_list in zip(uniqe_values,num_lists):
    identety_dic[uniqe_value]=num_list

# %%
identety_dic
# Out:
# {'TIGER': 0,
#  'DOG': 1,
#  'GIRAFFE': 2,
#  'HORSE': 3,
#  'BIRD': 4,
#  'COW': 5,
#  'BEAR': 6,
#  'DEER': 7,
#  'PANDA': 8,
#  'ELEPHANT': 9,
#  'ZEBRA': 10,
#  'CAT': 11,
#  'DOLPHIN': 12,
#  'KANGAROO': 13,
#  'LION': 14}

# %%
from matplotlib.image import imread
import cv2
import numpy as np
path=r'datasets/Animal'
path2=r'datasets/Animal/'
data_list=[]
target_list=[]
for root,dir,files in os.walk(path):
    for file in files:
        first_word=file.split('-',1)
        Image=f"{path2}{file}"
        convert_image =cv2.imread(Image)#,cv2.IMREAD_GRAYSCALE
        data_list.append(convert_image)#cv2.resize(convert_image, (28, 28))
        target_list.append(identety_dic[first_word[0]])

# %%
dataset=np.array(data_list)
final_target=np.array(target_list)
print(dataset.shape)
print(final_target.shape)
# Out:
# (1944, 224, 224, 3)
# (1944,)

# %%
final_data=np.reshape(dataset, (dataset.shape[0], -1))

# %%
final_data.shape
# Out:
# (1944, 150528)

# %% [markdown]
# Done now lets make test and traning sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(final_data, final_target, test_size=0.2, random_state=42)

# %%
y_test
# Out:
# array([ 8, 13,  0,  2, 11,  5, 14,  7, 10, 11, 11,  8, 14,  0,  2,  0,  6,
#         8,  5,  4,  7,  6,  2, 14,  1, 14,  4, 11, 13,  6,  0, 14,  0,  8,
#         9,  2,  6,  2, 12,  3, 14, 13,  6, 10,  2,  0, 10,  3, 14, 14,  2,
#         1,  3,  2,  4,  5,  5,  7,  7, 13, 10,  8,  3,  8,  1,  7, 11,  9,
#         9,  8, 14,  8, 10,  6,  3, 14,  0,  2,  4,  1,  2, 14,  7,  3, 12,
#         9, 11,  9,  1, 12,  7, 13,  9,  9,  6,  9,  0,  8,  0,  6, 14,  1,
#         8,  8, 12, 10, 11, 13,  4, 11,  3, 11, 13,  3,  7, 12,  2, 13,  5,
#        10,  0,  9,  3,  2,  9,  7, 13, 13,  0, 12,  3,  5,  8,  6, 11,  5,
#         3,  4,  0,  4,  4, 11,  1,  0,  5,  3,  1, 11,  4, 14, 11,  0,  4,
#         7, 10,  3,  9,  3,  3,  4,  8,  7,  3,  7, 10, 12, 13,  3,  3, 14,
#         1, 13,  6, 11,  6,  9,  8,  8,  0, 10,  4,  1,  3, 11, 13, 14,  6,
#         8, 10,  3,  2,  9,  8,  2,  4,  1, 12, 14,  3,  6,  7,  0, 14,  7,
#         5, 10,  5, 11, 10,  4,  4, 13,  3,  8,  1, 13,  6,  9,  0,  6,  9,
#         8,  0,  1,  6, 14, 11,  4,  4, 11, 14, 14,  8,  6, 13, 13, 10, 12,
#        10,  9,  0,  3, 14,  5, 13, 10,  4,  7, 10, 12,  9, 11, 12, 10,  4,
#        11,  2,  6, 11,  5,  6,  4,  7,  1,  8,  0, 10,  7,  6, 14, 10, 10,
#         6, 10, 14,  3,  5,  7,  9, 12,  6,  2,  7,  9, 13,  5,  9, 14, 14,
#         5, 14,  6,  1,  4, 14,  3, 10,  7,  1, 12, 11, 10,  7, 13,  7,  8,
#         4,  8,  3,  5,  3,  9,  7,  8, 10, 10, 13,  9,  5,  9,  8,  6,  5,
#         0,  5, 10, 11,  5, 11,  4,  7,  0,  8, 11, 10, 11,  1,  6,  0,  7,
#         8,  7,  5, 13,  5, 10, 12, 11, 10,  1,  9,  3, 14, 14,  8,  1, 12,
#         7,  8, 13,  8,  4, 10,  4, 12, 14,  7,  8,  7, 11,  9,  7, 10,  5,
#        12,  6, 12,  4,  6,  7,  5,  7, 11, 13,  8,  7,  5,  9, 12])

# %%
from sklearn.ensemble import RandomForestClassifier
forest_clf=RandomForestClassifier(random_state=42)

# %%
from sklearn.model_selection import cross_val_predict
y_probas_forest=cross_val_predict(forest_clf,X_train,y_train,cv=3)

# %%
y_probas_forest
# Out:
# array([11, 12,  7, ..., 12,  0,  5], shape=(1555,))

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_train,y_probas_forest)
cm
# Out:
# array([[37,  4,  9,  4,  6,  5,  1, 12,  5,  2,  3,  0,  1, 11,  6],
#        [ 6, 46,  6,  1,  8,  3,  5,  3,  2,  3,  5,  6,  2,  2,  5],
#        [ 8,  3, 65,  3,  5,  3,  1,  8,  0,  2,  2,  0,  4,  5,  4],
#        [ 6, 10,  4, 36, 10,  4,  3, 11,  2,  5,  1,  3,  2,  3,  2],
#        [ 2,  6,  2,  0, 64,  0,  0,  2,  6,  3,  5,  1,  7,  8,  5],
#        [ 6,  3, 16,  1,  3, 42, 11,  3,  5,  0,  2,  1,  3,  3,  7],
#        [ 3,  8,  1,  1,  5,  5, 43,  5,  7,  9,  1,  1,  6,  2,  1],
#        [ 5,  4,  4,  2, 14,  3,  0, 47,  1,  1,  1,  0,  1,  9,  2],
#        [ 5,  1,  0,  2,  2,  2,  1,  3, 73,  4,  4,  4,  0,  1,  1],
#        [ 4,  5, 10,  2,  1,  3,  7,  3,  5, 55,  2,  2,  2,  4,  2],
#        [ 9,  6, 15,  3,  1,  2,  1,  5,  1,  5, 46,  3,  1,  6,  1],
#        [ 6, 11,  2,  4,  7,  5,  0,  4,  2,  1,  1, 36,  3,  5,  7],
#        [ 0,  3,  1,  3,  3,  0,  1,  0,  1,  0,  0,  0, 97,  0,  1],
#        [ 5,  3, 11,  1, 12,  3,  1, 11,  0,  3,  3,  1,  3, 37,  8],
#        [12,  5,  2,  0, 11,  6,  5,  8,  2,  2,  2,  0,  1,  6, 39]])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.astype("float64"))
cross_val_score(forest_clf, X_train_scaled, y_train, cv=3, scoring="accuracy")
# Out:
# array([0.48747592, 0.48455598, 0.50965251])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
y_train_pred=cross_val_predict(forest_clf,X_train_scaled,y_train,cv=3)
ConfusionMatrixDisplay.from_predictions(y_train,y_train_pred)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ConfusionMatrixDisplay.from_predictions(y_train,y_train_pred,normalize="true",values_format=".0%")

# %%
sample_weight = (y_train_pred != y_train)
plt.rc('font', size=10)  # extra code
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred, sample_weight=sample_weight,normalize="true", values_format=".0%")
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred,
                                        sample_weight=sample_weight,
                                        normalize="pred", values_format=".0%")
